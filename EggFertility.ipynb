# %%
# !pip install ultralytics
# !pip install tqdm --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
# Importing required libraries
import os
import shutil
import random
from tqdm import tqdm
import ultralytics

# %%
# Checking ultralytics setup
ultralytics.checks()
# Out:
# Ultralytics 8.3.99 🚀 Python-3.10.12 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX A4000, 16005MiB)
# Setup complete ✅ (24 CPUs, 62.5 GB RAM, 155.2/2179.6 GB disk)

# %%
# Set the path for train, validation, and test directories on your local machine
train_path_img = "/home/bflserver01/Downloads/EggFer/train/images"  # Change this to your local train images path
train_path_label = "/home/bflserver01/Downloads/EggFer/train/labels"  # Change this to your local train labels path
val_path_img = "/home/bflserver01/Downloads/EggFer/valid/images"  # Change this to your local validation images path
val_path_label = "/home/bflserver01/Downloads/EggFer/valid/labels"  # Change this to your local validation labels path
test_path = "/home/bflserver01/Downloads/EggFer/test"  # Change this to your local test data path

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=/home/bflserver01/Downloads/EggFer/data.yaml epochs=50 imgsz=640 batch=8 project=/home/bflserver01/Downloads/EggFer/training_results  name=MultipleEggs50
# Out:
# New https://pypi.org/project/ultralytics/8.3.112 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.83 🚀 Python-3.11.5 torch-2.2.2+cu121 CUDA:0 (NVIDIA RTX A4000, 15985MiB)
# ...
